# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
n_pnts = int(1e6)

u = np.random.rand(n_pnts)

# %%
x = np.arccos(1 - 2 * u)
n_bins = 20
values, bins = np.histogram(x, bins=np.linspace(0, np.pi, n_bins))

dx = (np.pi - 0) / n_bins
values = (values / np.sum(values)) / dx



x_values = np.linspace(0, np.pi, 1000)

plt.figure(2)
plt.plot(bins[0:-1], values, '*r')
plt.plot(x_values, np.sin(x_values) / 2, '-b')
plt.xlabel("theta")
plt.ylabel("p(theta)")
# Out:
# Text(0, 0.5, 'p(theta)')

# %%
phi = 2*np.pi*np.random.rand(n_pnts)
x=np.sin(x)*np.cos(phi)
y=np.sin(x)*np.sin(phi)
z=np.cos(x)

# %%
fig=plt.figure()
ax=plt.axes(projection="3d")
ax.plot3d(x,y,z)
ax.plot3d(x,y,z)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-89c62ec862a9> in <module>
#       1 fig=plt.figure()
#       2 ax=plt.axes(projection="3d")
# ----> 3 ax.plot3d(x,y,z)
#
# AttributeError: 'Axes3DSubplot' object has no attribute 'plot3d'
